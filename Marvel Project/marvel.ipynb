# %% [markdown]
# Project Title: The Marvel Multiverse: A Data-Driven Analysis of Cinematic Success
# The Goal: Analyze what factors make a Marvel project successful by looking at the relationships between different cinematic universes, cast popularity, budgets, and audience/critic ratings.

# %% [markdown]
# 1. Data Cleaning & Preparation (The Unsung Hero Stage)
# The Issue: Looking at marvel_master.csv, you'll notice many missing values in fields like budget_usd, revenue_usd, box_office_usd, and scores.
#
# Your Task: Handle these missing values. Will you drop rows with missing financial data, fill them with zeros, or use a median?
#
# Categorical Encoding: Clean up the categorical columns like mcu_phase and universe. Standardize them so you don't have messy text groupings.

# %%
import pandas as pd
master= pd.read_csv('marvel_master.csv')
cast= pd.read_csv('marvel_cast.csv')
ratings= pd.read_csv('marvel_ratings.csv')
rag= pd.read_csv('marvel_rag.csv')

cast.head()
# Out:
#              title  year   tmdb_id          actor_name  \
# 0  Captain America  1944  106355.0        Dick Purcell
# 1  Captain America  1944  106355.0          Lorna Gray
# 2  Captain America  1944  106355.0       Lionel Atwill
# 3  Captain America  1944  106355.0  Charles Trowbridge
# 4  Captain America  1944  106355.0       Russell Hicks
#
#                          character  cast_order  actor_tmdb_id  popularity  \
# 0  Captain America / Grant Gardner           0          13970      0.3970
# 1                    Gail Richards           1          96719      0.4055
# 2                     Cyrus Maldor           2           2495      0.4445
# 3       Police Commissioner Dryden           3          96721      0.3023
# 4                   Mayor Randolph           4          13969      0.8038
#
#                                         profile_path
# 0  https://image.tmdb.org/t/p/w185/p0RZAW7uh1dIwu...
# 1  https://image.tmdb.org/t/p/w185/cdWxxF7weiJucc...
# 2  https://image.tmdb.org/t/p/w185/2KFwXY3fsMWWye...
# 3  https://image.tmdb.org/t/p/w185/l0pMZJiTfkxBOE...
# 4  https://image.tmdb.org/t/p/w185/5Pir7aPr3Iooqd...

# %%
import numpy as np
def convert_to_numeric(df, columns):
    for column in columns:
        if column in df.columns:
            df[column] = pd.to_numeric(df[column], errors='coerce')
        return df
    convert_to_numeric(master, ['budget_usd', 'scores', 'box_office_usd', 'revenue_usd'])

convert_to_numeric(master, ['budget_usd', 'scores', 'box_office_usd', 'revenue_usd'])

def convert_to_string(df, columns):
    for column in columns:
        if column in df.columns:
            df[column] = df[column].astype(str)
    return df

convert_to_string(master, ['imdb_id', 'type', 'genre','director','writer','actors','decade','tmdb_genres','top5_cast','poster_url'])

def replace_missing_values(df, columns, value):
    for column in columns:
        if column in df.columns:
            df[column].fillna(value, inplace=True)
    return df
replace_missing_values(master, ['budget_usd', 'scores', 'box_office_usd', 'revenue_usd','runtime_min','imdb_rating','imdb_votes','rt_score'
                                , 'metacritic_score','tmdb_id','tmdb_rating','tmdb_votes','popularity'], 0)

replace_missing_values(master, ['imdb_id', 'genre','writer','actors','decade','tmdb_genres','top5_cast','poster_url'], 'Nil')
replace_missing_values(master, ['plot','directors','producers','composer','tmdb_keywords','collection_name','tagline',
                                'episode_count','season_count', 'type'], 'Unknown')
replace_missing_values(master, ['awards'], 'Not Nominated')
replace_missing_values(master, ['rated'], 'Family')
replace_missing_values(master, ['spoken_languages'], 'English')
replace_missing_values(master, ['country','production_countries'], 'United States')
replace_missing_values(master, ['status'],'Forgotten')
replace_missing_values(master, ['network'], 'Disney+')

def to_category(df, columns):
    for column in columns:
        if column in df.columns:
            df[column] = df[column].astype('category')
    return df
to_category(master,['mcu_phase','status','type', 'is_animated','is_tv_series','is_mcu_canon','universe'])

def drop_columns(df, columns):
    for column in columns:
        if column in df.columns:
            df.drop(columns=[column], inplace=True)
    return df
drop_columns(master, ['website','production','language','director'])
def to_object(df, columns):
    for column in columns:
        if column in df.columns:
            df[column] = df[column].astype('object')
    return df

def to_integer(df, columns):
    for column in columns:
        if column in df.columns:
            df[column] = df[column].astype(int)
    return df
to_integer(master, ['year'])

def categorise(df, condition, choices, column_name='Era'):
    df[column_name] = np.select(condition, choices, default='Unknown')
    return df

condition = [
    master['year'] < 2000,
    (master['year'] >= 2000) & (master['year'] <= 2025),
    master['year'] == 2026
]
era = ['Classic', 'Modern', 'Current']

categorise(master, condition, era, column_name='Era')
to_category(master, ['Era'])
to_category(rag,['universe', 'mcu_phase'])
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_19952\1868672244.py:22: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'Unknown' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df[column].fillna(value, inplace=True)
#       id                      title  year           universe  mcu_phase  \
# 0      1            Captain America  1944            Pre-MCU    Pre-MCU
# 1      2     The Amazing Spider-Man  1977  Sony / Spider-Man    Pre-MCU
# 2      3                 Spider-Man  1977  Sony / Spider-Man    Pre-MCU
# 3      4                Dr. Strange  1978            Pre-MCU    Pre-MCU
# 4      5        The Incredible Hulk  1978            Pre-MCU    Pre-MCU
# ..   ...                        ...   ...                ...        ...
# 156  157      Venom: The Last Dance  2025  Sony / Spider-Man  Phase 5/6
# 157  158          Kraven the Hunter  2025  Sony / Spider-Man  Phase 5/6
# 158  159                 Wonder Man  2026                MCU  Phase 5/6
# 159  160      Daredevil: Born Again  2026                MCU  Phase 5/6
# 160  161  Spider-Man: Brand New Day  2026                MCU  Phase 5/6
#
#                                               document
# 0    Title: Captain America\nYear: 1944\nUniverse: ...
# 1    Title: The Amazing Spider-Man\nYear: 1977\nUni...
# 2    Title: Spider-Man\nYear: 1977\nUniverse: Sony ...
# 3    Title: Dr. Strange\nYear: 1978\nUniverse: Pre-...
# 4    Title: The Incredible Hulk\nYear: 1978\nUniver...
# ..                                                 ...
# 156  Title: Venom: The Last Dance\nYear: 2025\nUniv...
# 157  Title: Kraven the Hunter\nYear: 2025\nUniverse...
# 158  Title: Wonder Man\nYear: 2026\nUniverse: MCU\n...
# 159  Title: Daredevil: Born Again\nYear: 2026\nUniv...
# 160  Title: Spider-Man: Brand New Day\nYear: 2026\n...
#
# [161 rows x 6 columns]

# %% [markdown]
# 2. Joining Data (Connecting the Pieces)
# Your Task: Bring in external context. Use pandas merges to join marvel_master.csv with the other files:
#
# The Cast Connection: Group the marvel_cast.csv by movie to find the average actor popularity or the number of high-profile stars in a movie, then merge that summary dataframe back into your master dataset.
#
# The Ratings Merge: Compare how different review platforms scale their ratings by checking marvel_ratings.csv.

# %%
def merge_df(df1, df2, on_column, how, suffixes):
    merged_df = pd.merge(df1, df2, on=on_column, how=how, suffixes=suffixes)
    return merged_df
merged_df = merge_df(master, cast, on_column='title', how='left', suffixes=('', '_cast'))
merged_df
# Out:
#        id                      title  year     imdb_id   type     rated  \
# 0       1            Captain America  1944   tt0036697  movie  Approved
# 1       1            Captain America  1944   tt0036697  movie  Approved
# 2       1            Captain America  1944   tt0036697  movie  Approved
# 3       1            Captain America  1944   tt0036697  movie  Approved
# 4       1            Captain America  1944   tt0036697  movie  Approved
# ...   ...                        ...   ...         ...    ...       ...
# 2035  161  Spider-Man: Brand New Day  2026  tt22084616  movie    Family
# 2036  161  Spider-Man: Brand New Day  2026  tt22084616  movie    Family
# 2037  161  Spider-Man: Brand New Day  2026  tt22084616  movie    Family
# 2038  161  Spider-Man: Brand New Day  2026  tt22084616  movie    Family
# 2039  161  Spider-Man: Brand New Day  2026  tt22084616  movie    Family
#
#       runtime_min                       genre  \
# 0           244.0   Action, Adventure, Sci-Fi
# 1           244.0   Action, Adventure, Sci-Fi
# 2           244.0   Action, Adventure, Sci-Fi
# 3           244.0   Action, Adventure, Sci-Fi
# 4           244.0   Action, Adventure, Sci-Fi
# ...           ...                         ...
# 2035          0.0  Action, Adventure, Fantasy
# 2036          0.0  Action, Adventure, Fantasy
# 2037          0.0  Action, Adventure, Fantasy
# 2038          0.0  Action, Adventure, Fantasy
# 2039          0.0  Action, Adventure, Fantasy
#
#                                             writer  \
# 0     Royal K. Cole, Ronald Davidson, Basil Dickey
# 1     Royal K. Cole, Ronald Davidson, Basil Dickey
# 2     Royal K. Cole, Ronald Davidson, Basil Dickey
# 3     Royal K. Cole, Ronald Davidson, Basil Dickey
# 4     Royal K. Cole, Ronald Davidson, Basil Dickey
# ...                                            ...
# 2035         Chris McKenna, Erik Sommers, Stan Lee
# 2036         Chris McKenna, Erik Sommers, Stan Lee
# 2037         Chris McKenna, Erik Sommers, Stan Lee
# 2038         Chris McKenna, Erik Sommers, Stan Lee
# 2039         Chris McKenna, Erik Sommers, Stan Lee
#
#                                        actors  ...  tagline      Era  \
# 0     Dick Purcell, Lorna Gray, Lionel Atwill  ...  Unknown  Classic
# 1     Dick Purcell, Lorna Gray, Lionel Atwill  ...  Unknown  Classic
# 2     Dick Purcell, Lorna Gray, Lionel Atwill  ...  Unknown  Classic
# 3     Dick Purcell, Lorna Gray, Lionel Atwill  ...  Unknown  Classic
# 4     Dick Purcell, Lorna Gray, Lionel Atwill  ...  Unknown  Classic
# ...                                       ...  ...      ...      ...
# 2035         Tom Holland, Zendaya, Sadie Sink  ...  Unknown  Current
# 2036         Tom Holland, Zendaya, Sadie Sink  ...  Unknown  Current
# 2037         Tom Holland, Zendaya, Sadie Sink  ...  Unknown  Current
# 2038         Tom Holland, Zendaya, Sadie Sink  ...  Unknown  Current
# 2039         Tom Holland, Zendaya, Sadie Sink  ...  Unknown  Current
#
#      year_cast  tmdb_id_cast          actor_name  \
# 0       1944.0      106355.0        Dick Purcell
# 1       1944.0      106355.0          Lorna Gray
# 2       1944.0      106355.0       Lionel Atwill
# 3       1944.0      106355.0  Charles Trowbridge
# 4       1944.0      106355.0       Russell Hicks
# ...        ...           ...                 ...
# 2035    2026.0      969681.0        Eman Esfandi
# 2036    2026.0      969681.0         Keith David
# 2037    2026.0      969681.0     Zabryna Guevara
# 2038    2026.0      969681.0      Rosario Dawson
# 2039    2026.0      969681.0        Marisa Tomei
#
#                             character cast_order  actor_tmdb_id  \
# 0     Captain America / Grant Gardner        0.0        13970.0
# 1                       Gail Richards        1.0        96719.0
# 2                        Cyrus Maldor        2.0         2495.0
# 3          Police Commissioner Dryden        3.0        96721.0
# 4                      Mayor Randolph        4.0        13969.0
# ...                               ...        ...            ...
# 2035                              NaN       10.0      2243207.0
# 2036                              NaN       11.0        65827.0
# 2037                    Sheila Rivera       12.0       171955.0
# 2038                    Claire Temple       13.0         5916.0
# 2039                       May Parker       14.0         3141.0
#
#      popularity_cast                                       profile_path
# 0             0.3970  https://image.tmdb.org/t/p/w185/p0RZAW7uh1dIwu...
# 1             0.4055  https://image.tmdb.org/t/p/w185/cdWxxF7weiJucc...
# 2             0.4445  https://image.tmdb.org/t/p/w185/2KFwXY3fsMWWye...
# 3             0.3023  https://image.tmdb.org/t/p/w185/l0pMZJiTfkxBOE...
# 4             0.8038  https://image.tmdb.org/t/p/w185/5Pir7aPr3Iooqd...
# ...              ...                                                ...
# 2035          0.3494  https://image.tmdb.org/t/p/w185/lrDfNC81vTkFW9...
# 2036          2.0395  https://image.tmdb.org/t/p/w185/1x0QXavmIy3Qmh...
# 2037          0.7338  https://image.tmdb.org/t/p/w185/7NlCmTZoauvyqj...
# 2038          2.3905  https://image.tmdb.org/t/p/w185/1mm7JGHIUX3GRR...
# 2039          2.7640  https://image.tmdb.org/t/p/w185/5w6qM8FWsl5Sut...
#
# [2040 rows x 55 columns]

# %%
replace_missing_values(cast, ['profile_path'], 'Nil')
#cast.head(50)
grouping= cast.groupby('title').agg({'popularity':'mean'}).sort_values(by='popularity',ascending=False)
grouping
merged_df = merge_df(master, grouping, on_column='title', how='left', suffixes=('', '_cast'))
merged_df
# Out:
#       id                      title  year     imdb_id    type     rated  \
# 0      1            Captain America  1944   tt0036697   movie  Approved
# 1      2     The Amazing Spider-Man  1977   tt0076975  series     TV-PG
# 2      3                 Spider-Man  1977   tt0076975  series     TV-PG
# 3      4                Dr. Strange  1978   tt0077469   movie     TV-PG
# 4      5        The Incredible Hulk  1978         nan     nan    Family
# ..   ...                        ...   ...         ...     ...       ...
# 156  157      Venom: The Last Dance  2025         nan     nan    Family
# 157  158          Kraven the Hunter  2025         nan     nan    Family
# 158  159                 Wonder Man  2026  tt21066182  series     TV-14
# 159  160      Daredevil: Born Again  2026  tt40791652   movie    Family
# 160  161  Spider-Man: Brand New Day  2026  tt22084616   movie    Family
#
#      runtime_min                       genre  \
# 0          244.0   Action, Adventure, Sci-Fi
# 1           60.0    Action, Adventure, Crime
# 2           60.0    Action, Adventure, Crime
# 3           93.0             Action, Fantasy
# 4            0.0                         nan
# ..           ...                         ...
# 156          0.0                         nan
# 157          0.0                         nan
# 158          0.0   Action, Adventure, Comedy
# 159          0.0                   Talk-Show
# 160          0.0  Action, Adventure, Fantasy
#
#                                            writer  \
# 0    Royal K. Cole, Ronald Davidson, Basil Dickey
# 1                                             nan
# 2                                             nan
# 3       Philip DeGuere Jr., Steve Ditko, Stan Lee
# 4                                             nan
# ..                                            ...
# 156                                           nan
# 157                                           nan
# 158                         Destin Daniel Cretton
# 159                                           nan
# 160         Chris McKenna, Erik Sommers, Stan Lee
#
#                                              actors  ...  \
# 0           Dick Purcell, Lorna Gray, Lionel Atwill  ...
# 1    Nicholas Hammond, Robert F. Simon, Chip Fields  ...
# 2    Nicholas Hammond, Robert F. Simon, Chip Fields  ...
# 3       Peter Hooten, Clyde Kusatsu, Jessica Walter  ...
# 4                                               nan  ...
# ..                                              ...  ...
# 156                                             nan  ...
# 157                                             nan  ...
# 158     Yahya Abdul-Mateen II, Ben Kingsley, X Mayo  ...
# 159                                             nan  ...
# 160                Tom Holland, Zendaya, Sadie Sink  ...
#
#                                             poster_url  \
# 0    https://image.tmdb.org/t/p/w500/nBRcChS66NohR3...
# 1    https://image.tmdb.org/t/p/w500/jNxRHZ2cxVkNRt...
# 2    https://image.tmdb.org/t/p/w500/jNxRHZ2cxVkNRt...
# 3    https://image.tmdb.org/t/p/w500/hEyHVgBE28Jl13...
# 4    https://image.tmdb.org/t/p/w500/3apbGlabEmgR1j...
# ..                                                 ...
# 156  https://image.tmdb.org/t/p/w500/vGXptEdgZIhPg3...
# 157  https://image.tmdb.org/t/p/w500/1GvBhRxY6MELDf...
# 158  https://image.tmdb.org/t/p/w500/6yy9nQlFt2l6UV...
# 159  https://image.tmdb.org/t/p/w500/pXr32DqmkiEJTQ...
# 160  https://image.tmdb.org/t/p/w500/yyB2VJEW3an2xC...
#
#          production_countries           spoken_languages  episode_count  \
# 0    United States of America                    English        Unknown
# 1    United States of America                    English        Unknown
# 2    United States of America                    English        Unknown
# 3    United States of America                    English        Unknown
# 4    United States of America                    English        Unknown
# ..                        ...                        ...            ...
# 156  United States of America                    English        Unknown
# 157  United States of America  English, Russian, Turkish        Unknown
# 158  United States of America                    English            8.0
# 159  United States of America                    English            9.0
# 160  United States of America                    English        Unknown
#
#     season_count           network            status  \
# 0        Unknown           Disney+          Released
# 1        Unknown           Disney+          Released
# 2        Unknown           Disney+          Released
# 3        Unknown           Disney+          Released
# 4        Unknown           Disney+          Released
# ..           ...               ...               ...
# 156      Unknown           Disney+          Released
# 157      Unknown           Disney+          Released
# 158          2.0           Disney+  Returning Series
# 159          1.0  YouTube, Disney+  Returning Series
# 160      Unknown           Disney+   Post Production
#
#                                                tagline      Era  \
# 0                                              Unknown  Classic
# 1    The world's favorite adventure super hero in l...  Classic
# 2    The world's favorite adventure super hero in l...  Classic
# 3    Battle of the sorcerers burns the screen with ...  Classic
# 4    She loved the man... would the beast destroy t...  Classic
# ..                                                 ...      ...
# 156                           'Til death do they part.   Modern
# 157                Villains aren't born. They're made.   Modern
# 158  He was born to play this role, but the spotlig...  Current
# 159                                            Unknown  Current
# 160                                            Unknown  Current
#
#     popularity_cast
# 0          0.595837
# 1          1.240443
# 2          0.986493
# 3          0.524300
# 4          1.061639
# ..              ...
# 156        1.765047
# 157        1.024213
# 158        1.568075
# 159        1.620962
# 160        2.860000
#
# [161 rows x 48 columns]

# %%
ratings
replace_missing_values(ratings, ['score'], 0)
to_category(ratings, ['source'])

def strip(df, columns):
    for column in columns:
        if column in df.columns:
            df[column] = df[column].astype(str).str.replace(r'/100|%', '', regex=True).str.strip()
    return df
strip(ratings, ['score'])
convert_to_numeric(ratings, ['score'])
# Out:
#                          title  year source  score
# 0              Captain America  1944   IMDb  5.300
# 1              Captain America  1944   TMDB  5.400
# 2       The Amazing Spider-Man  1977   IMDb  6.200
# 3       The Amazing Spider-Man  1977   TMDB  6.300
# 4                   Spider-Man  1977   IMDb  6.200
# ..                         ...   ...    ...    ...
# 549                 Wonder Man  2026   IMDb  7.400
# 550                 Wonder Man  2026   TMDB  7.019
# 551      Daredevil: Born Again  2026   IMDb  7.800
# 552      Daredevil: Born Again  2026   TMDB  7.000
# 553  Spider-Man: Brand New Day  2026   TMDB  0.000
#
# [554 rows x 4 columns]

# %%
#grouped_ratings = ratings.groupby(['title']).agg({'score':'mean'}).sort_values(by='score',ascending=False)
#grouped_ratings
master
# Out:
#       id                      title  year     imdb_id    type     rated  \
# 0      1            Captain America  1944   tt0036697   movie  Approved
# 1      2     The Amazing Spider-Man  1977   tt0076975  series     TV-PG
# 2      3                 Spider-Man  1977   tt0076975  series     TV-PG
# 3      4                Dr. Strange  1978   tt0077469   movie     TV-PG
# 4      5        The Incredible Hulk  1978         nan     nan    Family
# ..   ...                        ...   ...         ...     ...       ...
# 156  157      Venom: The Last Dance  2025         nan     nan    Family
# 157  158          Kraven the Hunter  2025         nan     nan    Family
# 158  159                 Wonder Man  2026  tt21066182  series     TV-14
# 159  160      Daredevil: Born Again  2026  tt40791652   movie    Family
# 160  161  Spider-Man: Brand New Day  2026  tt22084616   movie    Family
#
#      runtime_min                       genre  \
# 0          244.0   Action, Adventure, Sci-Fi
# 1           60.0    Action, Adventure, Crime
# 2           60.0    Action, Adventure, Crime
# 3           93.0             Action, Fantasy
# 4            0.0                         nan
# ..           ...                         ...
# 156          0.0                         nan
# 157          0.0                         nan
# 158          0.0   Action, Adventure, Comedy
# 159          0.0                   Talk-Show
# 160          0.0  Action, Adventure, Fantasy
#
#                                            writer  \
# 0    Royal K. Cole, Ronald Davidson, Basil Dickey
# 1                                             nan
# 2                                             nan
# 3       Philip DeGuere Jr., Steve Ditko, Stan Lee
# 4                                             nan
# ..                                            ...
# 156                                           nan
# 157                                           nan
# 158                         Destin Daniel Cretton
# 159                                           nan
# 160         Chris McKenna, Erik Sommers, Stan Lee
#
#                                              actors  ...  \
# 0           Dick Purcell, Lorna Gray, Lionel Atwill  ...
# 1    Nicholas Hammond, Robert F. Simon, Chip Fields  ...
# 2    Nicholas Hammond, Robert F. Simon, Chip Fields  ...
# 3       Peter Hooten, Clyde Kusatsu, Jessica Walter  ...
# 4                                               nan  ...
# ..                                              ...  ...
# 156                                             nan  ...
# 157                                             nan  ...
# 158     Yahya Abdul-Mateen II, Ben Kingsley, X Mayo  ...
# 159                                             nan  ...
# 160                Tom Holland, Zendaya, Sadie Sink  ...
#
#                     collection_name  \
# 0                           Unknown
# 1        Spider-Man (TV) Collection
# 2        Spider-Man (TV) Collection
# 3                           Unknown
# 4    The Incredible Hulk Collection
# ..                              ...
# 156                Venom Collection
# 157                         Unknown
# 158                         Unknown
# 159                         Unknown
# 160     Spider-Man (MCU) Collection
#
#                                             poster_url  \
# 0    https://image.tmdb.org/t/p/w500/nBRcChS66NohR3...
# 1    https://image.tmdb.org/t/p/w500/jNxRHZ2cxVkNRt...
# 2    https://image.tmdb.org/t/p/w500/jNxRHZ2cxVkNRt...
# 3    https://image.tmdb.org/t/p/w500/hEyHVgBE28Jl13...
# 4    https://image.tmdb.org/t/p/w500/3apbGlabEmgR1j...
# ..                                                 ...
# 156  https://image.tmdb.org/t/p/w500/vGXptEdgZIhPg3...
# 157  https://image.tmdb.org/t/p/w500/1GvBhRxY6MELDf...
# 158  https://image.tmdb.org/t/p/w500/6yy9nQlFt2l6UV...
# 159  https://image.tmdb.org/t/p/w500/pXr32DqmkiEJTQ...
# 160  https://image.tmdb.org/t/p/w500/yyB2VJEW3an2xC...
#
#          production_countries           spoken_languages episode_count  \
# 0    United States of America                    English       Unknown
# 1    United States of America                    English       Unknown
# 2    United States of America                    English       Unknown
# 3    United States of America                    English       Unknown
# 4    United States of America                    English       Unknown
# ..                        ...                        ...           ...
# 156  United States of America                    English       Unknown
# 157  United States of America  English, Russian, Turkish       Unknown
# 158  United States of America                    English           8.0
# 159  United States of America                    English           9.0
# 160  United States of America                    English       Unknown
#
#     season_count           network            status  \
# 0        Unknown           Disney+          Released
# 1        Unknown           Disney+          Released
# 2        Unknown           Disney+          Released
# 3        Unknown           Disney+          Released
# 4        Unknown           Disney+          Released
# ..           ...               ...               ...
# 156      Unknown           Disney+          Released
# 157      Unknown           Disney+          Released
# 158          2.0           Disney+  Returning Series
# 159          1.0  YouTube, Disney+  Returning Series
# 160      Unknown           Disney+   Post Production
#
#                                                tagline      Era
# 0                                              Unknown  Classic
# 1    The world's favorite adventure super hero in l...  Classic
# 2    The world's favorite adventure super hero in l...  Classic
# 3    Battle of the sorcerers burns the screen with ...  Classic
# 4    She loved the man... would the beast destroy t...  Classic
# ..                                                 ...      ...
# 156                           'Til death do they part.   Modern
# 157                Villains aren't born. They're made.   Modern
# 158  He was born to play this role, but the spotlig...  Current
# 159                                            Unknown  Current
# 160                                            Unknown  Current
#
# [161 rows x 47 columns]

# %% [markdown]
# 3. Summary Statistics & Aggregation (Finding Patterns)
# Your Task: Group the data by universe (e.g., MCU vs. Sony vs. Pre-MCU) or mcu_phase (Phase 1, Phase 2, etc.).
#
# Metrics: Calculate the average budget, return on investment (ROI = Revenue / Budget), and mean IMDb/TMDB rating for each group.

# %%
grouping= master.groupby(['mcu_phase', 'universe'], sort=True).agg({'title':'count'}).sort_values(by='title',ascending=False)
grouping
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_19952\3185412229.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouping= master.groupby(['mcu_phase', 'universe'], sort=True).agg({'title':'count'}).sort_values(by='title',ascending=False)
#                              title
# mcu_phase universe
# Pre-MCU   Pre-MCU               27
# Non-MCU   MCU                   25
# Phase 5/6 MCU                   22
# Phase 4   MCU                   18
# Non-MCU   Fox / X-Men           14
#           Netflix Marvel        13
# Phase 3   MCU                   11
# Pre-MCU   Sony / Spider-Man      6
# Non-MCU   Sony / Spider-Man      6
# Phase 2   MCU                    6
# Phase 1   MCU                    6
# Pre-MCU   Fox / X-Men            3
# Phase 5/6 Sony / Spider-Man      3
#           Fox / X-Men            1
# Phase 2   Fox / X-Men            0
# Phase 1   Netflix Marvel         0
#           Pre-MCU                0
# Non-MCU   Pre-MCU                0
# Phase 1   Fox / X-Men            0
# Phase 3   Pre-MCU                0
#           Netflix Marvel         0
#           Fox / X-Men            0
# Phase 2   Sony / Spider-Man      0
#           Netflix Marvel         0
#           Pre-MCU                0
# Phase 1   Sony / Spider-Man      0
# Phase 3   Sony / Spider-Man      0
# Phase 4   Pre-MCU                0
#           Sony / Spider-Man      0
#           Fox / X-Men            0
#           Netflix Marvel         0
# Phase 5/6 Netflix Marvel         0
#           Pre-MCU                0
# Pre-MCU   Netflix Marvel         0
#           MCU                    0

# %%
roi= master['revenue_usd'] / master['budget_usd']
average_budget= master['budget_usd'].mean()
mean_rating= master['tmdb_rating'].mean()

print(roi)
print(average_budget)
print(mean_rating)

date= pd.to_datetime(master['year'], errors='coerce').dt.year
date
# Out:
# 0           NaN
# 1           NaN
# 2           NaN
# 3           NaN
# 4           NaN
#          ...
# 156    3.991147
# 157    0.477512
# 158         NaN
# 159         NaN
# 160         NaN
# Length: 161, dtype: float64
# 74163975.1552795
# 4.763155279503106
# 0      1970
# 1      1970
# 2      1970
# 3      1970
# 4      1970
#        ...
# 156    1970
# 157    1970
# 158    1970
# 159    1970
# 160    1970
# Name: year, Length: 161, dtype: int32

# %% [markdown]
# 4. Correlation & Deep Dive (The Core EDA)
# Your Task: Test assumptions using correlation.
#
# Does a higher budget actually guarantee a higher box office return or a better rating?
#
# Does a cast with a higher average popularity score lead to better movie ratings?
#
# Visualizations: Create a correlation heatmap using seaborn to show these relationships instantly. Use matplotlib scatter plots to track Budget vs. Revenue or Box Office across different universes.

# %%
convert_to_numeric(master, ['popularity'])
import matplotlib.pyplot as plt
import seaborn as sns
sns.heatmap(data= master[['popularity','tmdb_rating']].corr(), annot=True, cmap='coolwarm', fmt='.2f')
plt.title('Heatmap of Popularity vs TMDB Rating', fontsize= 16, fontweight= 'bold', color= 'black')
plt.xlabel('Popularity')
plt.ylabel('TMDB Rating')
plt.show()
#cast

# %%
fig, ax = plt.subplots(figsize=(10, 6))
sns.heatmap(data= master[['budget_usd','box_office_usd','tmdb_rating']].corr(), annot=True, cmap='coolwarm', fmt='.2f')
plt.title('Heatmap of Budget, Box Office, and TMDB Rating Correlation', fontsize= 16, fontstyle= 'italic', color= 'black')
ax.set_xlabel('Correlation', fontsize= 12, fontweight= 'bold', color= 'black')
ax.set_ylabel('Features', fontsize= 12, fontweight= 'bold', color= 'black')
plt.show()

# %%
sns.scatterplot(data= master,x='budget_usd', y= 'revenue_usd',hue= 'universe', s= 100)
plt.title('Plot of Budget vs Revenue', fontsize= 16, color= 'black')
plt.xlabel('Budget (USD)', fontsize= 12, fontweight= 'bold', color= 'black')
plt.ylabel('Revenue (USD)', fontsize= 12, fontweight= 'bold', color= 'black')
plt.show()

# %%
import datetime as dt
master.head()
date= pd.to_datetime(master['year'], errors='coerce').dt.year
today= dt.date.today()
age_diff= today.year - master['year']
age_egu= age_diff == master['age_years']

# %%
master.head()
# Out:
#    id                   title  year    imdb_id    type     rated  runtime_min  \
# 0   1         Captain America  1944  tt0036697   movie  Approved        244.0
# 1   2  The Amazing Spider-Man  1977  tt0076975  series     TV-PG         60.0
# 2   3              Spider-Man  1977  tt0076975  series     TV-PG         60.0
# 3   4             Dr. Strange  1978  tt0077469   movie     TV-PG         93.0
# 4   5     The Incredible Hulk  1978        nan     nan    Family          0.0
#
#                        genre                                        writer  \
# 0  Action, Adventure, Sci-Fi  Royal K. Cole, Ronald Davidson, Basil Dickey
# 1   Action, Adventure, Crime                                           nan
# 2   Action, Adventure, Crime                                           nan
# 3            Action, Fantasy     Philip DeGuere Jr., Steve Ditko, Stan Lee
# 4                        nan                                           nan
#
#                                            actors  ...  \
# 0         Dick Purcell, Lorna Gray, Lionel Atwill  ...
# 1  Nicholas Hammond, Robert F. Simon, Chip Fields  ...
# 2  Nicholas Hammond, Robert F. Simon, Chip Fields  ...
# 3     Peter Hooten, Clyde Kusatsu, Jessica Walter  ...
# 4                                             nan  ...
#
#                   collection_name  \
# 0                         Unknown
# 1      Spider-Man (TV) Collection
# 2      Spider-Man (TV) Collection
# 3                         Unknown
# 4  The Incredible Hulk Collection
#
#                                           poster_url  \
# 0  https://image.tmdb.org/t/p/w500/nBRcChS66NohR3...
# 1  https://image.tmdb.org/t/p/w500/jNxRHZ2cxVkNRt...
# 2  https://image.tmdb.org/t/p/w500/jNxRHZ2cxVkNRt...
# 3  https://image.tmdb.org/t/p/w500/hEyHVgBE28Jl13...
# 4  https://image.tmdb.org/t/p/w500/3apbGlabEmgR1j...
#
#        production_countries  spoken_languages episode_count season_count  \
# 0  United States of America           English       Unknown      Unknown
# 1  United States of America           English       Unknown      Unknown
# 2  United States of America           English       Unknown      Unknown
# 3  United States of America           English       Unknown      Unknown
# 4  United States of America           English       Unknown      Unknown
#
#    network    status                                            tagline  \
# 0  Disney+  Released                                            Unknown
# 1  Disney+  Released  The world's favorite adventure super hero in l...
# 2  Disney+  Released  The world's favorite adventure super hero in l...
# 3  Disney+  Released  Battle of the sorcerers burns the screen with ...
# 4  Disney+  Released  She loved the man... would the beast destroy t...
#
#        Era
# 0  Classic
# 1  Classic
# 2  Classic
# 3  Classic
# 4  Classic
#
# [5 rows x 47 columns]
